# %% [markdown]
# # Top Songs - Data Science Analysis
#
# I took a dataset from kaggle, labeled "Top Spotify songs" (https://www.kaggle.com/datasets/leonardopena/top-spotify-songs-from-20102019-by-year?resource=download). It contains the top songs by year in the world by spotify. This dataset has several variables about the songs and is based on Billboard.

# %% [markdown]
# - ID: song id
# - title: title of the song
# - artist: artist of the song
# - top genre: the genre of the track
# - year: Song's year in the Billboard
# - bpm: Beats.Per.Minute - The tempo of the song.
# - Energy: The energy of a song - the higher the value, the more energtic. song
# - dnce: Danceability - The higher the value, the easier it is to dance to this song.
# - dB: Loudness - The higher the value, the louder the song
# - live: Liveness - The higher the value, the more likely the song is a live recording
# - Valence - The higher the value, the more positive mood for the song.
# - Length - The duration of the song.
# - Acousticness - The higher the value the more acoustic the song is.
# - Speechiness - The higher the value the more spoken word the song contains.
# - duration: length of the song

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
songs = pd.read_csv('data/top_songs.csv', encoding='windows-1252')
songs
# Out:
#      Unnamed: 0                                              title
# 0             1                                   Hey, Soul Sister  \
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val
# 0               Train       neo mellow  2010   97    89    67  -4     8   80  \
# 1              Eminem  detroit hip hop  2010   87    93    75  -5    52   64
# 2               Kesha        dance pop  2010  120    84    76  -3    29   71
# 3           Lady Gaga        dance pop  2010  119    92    70  -4     8   71
# 4          Bruno Mars              pop  2010  109    84    64  -5     9   43
# ..                ...              ...   ...  ...   ...   ...  ..   ...  ...
# 598       Mark Ronson        dance pop  2019  104    66    61  -7    20   16
# 599        Ed Sheeran              pop  2019   95    79    75  -6     7   61
# 600         DJ Khaled        dance pop  2019  136    76    53  -5     9   65
# 601       Mark Ronson        dance pop  2019  114    79    60  -6    42   24
# 602  The Chainsmokers       electropop  2019  150    44    70  -9    13   23
#
#      dur  acous  spch  pop
# 0    217     19     4   83
# 1    263     24    23   82
# 2    200     10    14   80
# 3    295      0     4   79
# 4    221      2     4   78
# ..   ...    ...   ...  ...
# 598  176      1     3   75
# 599  206     21    12   75
# 600  260      7    34   70
# 601  217      1     7   69
# 602  213      6     6   67
#
# [603 rows x 15 columns]

# %%
songs.head(10)
# Out:
#    Unnamed: 0                                       title         artist
# 0           1                            Hey, Soul Sister          Train  \
# 1           2                        Love The Way You Lie         Eminem
# 2           3                                     TiK ToK          Kesha
# 3           4                                 Bad Romance      Lady Gaga
# 4           5                        Just the Way You Are     Bruno Mars
# 5           6                                        Baby  Justin Bieber
# 6           7                                    Dynamite      Taio Cruz
# 7           8                                     Secrets    OneRepublic
# 8           9  Empire State of Mind (Part II) Broken Down    Alicia Keys
# 9          10                    Only Girl (In The World)        Rihanna
#
#          top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch
# 0       neo mellow  2010   97    89    67  -4     8   80  217     19     4  \
# 1  detroit hip hop  2010   87    93    75  -5    52   64  263     24    23
# 2        dance pop  2010  120    84    76  -3    29   71  200     10    14
# 3        dance pop  2010  119    92    70  -4     8   71  295      0     4
# 4              pop  2010  109    84    64  -5     9   43  221      2     4
# 5     canadian pop  2010   65    86    73  -5    11   54  214      4    14
# 6        dance pop  2010  120    78    75  -4     4   82  203      0     9
# 7        dance pop  2010  148    76    52  -6    12   38  225      7     4
# 8          hip pop  2010   93    37    48  -8    12   14  216     74     3
# 9    barbadian pop  2010  126    72    79  -4     7   61  235     13     4
#
#    pop
# 0   83
# 1   82
# 2   80
# 3   79
# 4   78
# 5   77
# 6   77
# 7   77
# 8   76
# 9   73

# %%
songs.sample(5)
# Out:
#      Unnamed: 0                             title         artist
# 396         397                           Company  Justin Bieber  \
# 571         572  Tell Me You Love Me - NOTD Remix    Demi Lovato
# 591         592   All Around The World (La La La)          R3HAB
# 327         328                     Broken Arrows         Avicii
# 463         464                     There for You  Martin Garrix
#
#         top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 396  canadian pop  2016   95    80    59  -5     8   43  208     13     6   72
# 571     dance pop  2018  102    77    58  -5     9   76  182      5     8   44
# 591      big room  2019  125    86    73  -5    11   52  148     48     3   82
# 327      big room  2015  116    67    63  -7    10   29  233      5     5   65
# 463      big room  2017  106    64    61  -8    12   13  222     12     6   76

# %%
songs.shape
# Out:
# (603, 15)

# %%
# Drop the "Unnamed: 0" column
songs = songs.drop("Unnamed: 0", axis=1)

# %%
#check for dublicates
duplicateRows = songs[songs.duplicated()]
duplicateRows
# Out:
# Empty DataFrame
# Columns: [title, artist, top genre, year, bpm, nrgy, dnce, dB, live, val, dur, acous, spch, pop]
# Index: []

# %%
#check for empty cells
songs[songs.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [title, artist, top genre, year, bpm, nrgy, dnce, dB, live, val, dur, acous, spch, pop]
# Index: []

# %%
#check the column data types
songs.dtypes
# Out:
# title        object
# artist       object
# top genre    object
# year          int64
# bpm           int64
# nrgy          int64
# dnce          int64
# dB            int64
# live          int64
# val           int64
# dur           int64
# acous         int64
# spch          int64
# pop           int64
# dtype: object

# %% [markdown]
# # possible research questions:
# - What genres are present? what are the most common genres?
# - How does the popularity (pop) of songs vary across different genres (top genre)?
# - Which artists are popular over time?
# - What is the average energy (nrgy) and danceability (dnce) of different genres?
# - Does the popularity (pop) of a song correlate with its energy level (nrgy)?
# - Is there a relationship between the tempo (bpm) and energy (nrgy) of songs?
#
#
# - does the bpm correlate with a genre?
# - do the genres popular in a year stay the same over time?
#
# 7-10 - one = prediction/classification

# %% [markdown]
# ## what genres are present? what are the most common genres?

# %%
songs["top genre"].unique()
# Out:
# array(['neo mellow', 'detroit hip hop', 'dance pop', 'pop',
#        'canadian pop', 'hip pop', 'barbadian pop', 'atl hip hop',
#        'australian pop', 'indie pop', 'art pop', 'colombian pop',
#        'big room', 'british soul', 'chicago rap', 'acoustic pop',
#        'permanent wave', 'boy band', 'baroque pop', 'celtic rock',
#        'electro', 'complextro', 'canadian hip hop', 'candy pop',
#        'alaska indie', 'folk-pop', 'metropopolis', 'house',
#        'australian hip hop', 'electropop', 'australian dance',
#        'hollywood', 'canadian contemporary r&b',
#        'irish singer-songwriter', 'tropical house', 'belgian edm',
#        'french indie pop', 'hip hop', 'danish pop', 'latin',
#        'canadian latin', 'electronic trap', 'edm', 'electro house',
#        'downtempo', 'brostep', 'contemporary country', 'moroccan pop',
#        'escape room', 'alternative r&b'], dtype=object)

# %% [markdown]
# All the genres present in the dataset are listed above. Now we have a look at the most popular songs in the pop genre sorted by popularity.

# %%
songs_pop = songs[songs['top genre']=='pop']
songs_pop_sorted = songs_pop.sort_values(by='pop', ascending=False)
songs_pop_sorted.head(10)
# Out:
#                                                  title         artist
# 572                                           Memories       Maroon 5  \
# 574                                  Someone You Loved  Lewis Capaldi
# 576                                  How Do You Sleep?      Sam Smith
# 577  South of the Border (feat. Camila Cabello & Ca...     Ed Sheeran
# 443                                       Shape of You     Ed Sheeran
# 584                    Beautiful People (feat. Khalid)     Ed Sheeran
# 211                                       Stay With Me      Sam Smith
# 587                  I Don't Care (with Justin Bieber)     Ed Sheeran
# 510                                          I Like It        Cardi B
# 269                               I'm Not The Only One      Sam Smith
#
#     top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 572       pop  2019   91    32    76  -7     8   57  189     84     5   99
# 574       pop  2019  110    41    50  -6    11   45  182     75     3   96
# 576       pop  2019  111    68    48  -5     8   35  202     15     9   93
# 577       pop  2019   98    62    86  -6     9   67  204     15     8   92
# 443       pop  2017   96    65    83  -3     9   93  234     58     8   87
# 584       pop  2019   93    65    64  -8     8   55  198     12    19   86
# 211       pop  2014   84    42    42  -6    11   18  173     59     4   85
# 587       pop  2019  102    68    80  -5     9   84  220      9     4   85
# 510       pop  2018  136    73    82  -4    37   65  253     10    13   85
# 269       pop  2015   82    49    68  -6     8   49  239     53     4   84

# %% [markdown]
# The following code puts out the songs mit the highest bpm values.

# %%
max_bpm = songs['bpm'].max()
song_with_max_bpm = songs[songs['bpm'] == max_bpm]
song_with_max_bpm
# Out:
#                title   artist      top genre  year  bpm  nrgy  dnce  dB  live
# 276  FourFiveSeconds  Rihanna  barbadian pop  2015  206    27    58  -6    13  \
#
#      val  dur  acous  spch  pop
# 276   35  188     88     5   80

# %%
songs[songs['bpm'] > 200].head(10) #output: songs with bpm > 200
# Out:
#                                    title      artist      top genre  year
# 200  How Ya Doin'? (feat. Missy Elliott)  Little Mix      dance pop  2013  \
# 276                      FourFiveSeconds     Rihanna  barbadian pop  2015
# 362                     L.A.LOVE (la la)      Fergie      dance pop  2015
#
#      bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 200  201    95    36  -3    37   51  211      9    48   50
# 276  206    27    58  -6    13   35  188     88     5   80
# 362  202    39    48  -8    26   27  193      2     9    0

# %%
most_frequent_genres = songs["top genre"].value_counts()
# Display the most frequent genres
most_frequent_genres
# Out:
# top genre
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# art pop                        8
# complextro                     6
# hip pop                        6
# australian dance               6
# atl hip hop                    5
# australian pop                 5
# edm                            5
# permanent wave                 4
# latin                          4
# hip hop                        4
# colombian pop                  3
# tropical house                 3
# brostep                        2
# downtempo                      2
# electronic trap                2
# belgian edm                    2
# escape room                    2
# folk-pop                       2
# electro                        2
# indie pop                      2
# detroit hip hop                2
# candy pop                      2
# acoustic pop                   2
# canadian hip hop               2
# baroque pop                    2
# celtic rock                    1
# moroccan pop                   1
# contemporary country           1
# chicago rap                    1
# electro house                  1
# australian hip hop             1
# canadian latin                 1
# house                          1
# danish pop                     1
# french indie pop               1
# alaska indie                   1
# irish singer-songwriter        1
# hollywood                      1
# metropopolis                   1
# alternative r&b                1
# Name: count, dtype: int64

# %%
#visualization of the results above
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

colors = sns.color_palette('pastel')[:10]
most_frequent_genres[:10].plot(kind='bar', color = colors)

plt.xlabel('Genres')
plt.ylabel('Frequency')
plt.title('Top 10 Most Frequent Genres')

plt.show()

# %% [markdown]
# For comparison, the 10 most popular songs in the dance pop genre sorted by popularity are put out with the following code. One visible difference is, that songs from the dance pop genre have a higher bpm, which may be a difference defining the genre.

# %%
songs_dancepop = songs[songs['top genre']=='dance pop']
songs_dancepop_sorted = songs_dancepop.sort_values(by='pop', ascending=False)
songs_dancepop_sorted.head(10)
# Out:
#                            title          artist  top genre  year  bpm  nrgy
# 573          Lose You To Love Me    Selena Gomez  dance pop  2019  102    34  \
# 139          Underneath the Tree  Kelly Clarkson  dance pop  2013  160    81
# 508     One Kiss (with Dua Lipa)   Calvin Harris  dance pop  2018  124    86
# 586             Don't Call Me Up           Mabel  dance pop  2019   99    88
# 509    Havana (feat. Young Thug)  Camila Cabello  dance pop  2018  105    52
# 514                        IDGAF        Dua Lipa  dance pop  2018   97    54
# 513         no tears left to cry   Ariana Grande  dance pop  2018  122    71
# 589  Giant (with Rag'n'Bone Man)   Calvin Harris  dance pop  2019  122    89
# 511                    New Rules        Dua Lipa  dance pop  2018  116    70
# 518                    Attention    Charlie Puth  dance pop  2018  100    61
#
#      dnce  dB  live  val  dur  acous  spch  pop
# 573    51  -9    21    9  206     58     4   97
# 139    51  -5    21   69  230      0     5   88
# 508    79  -3     8   59  215      4    11   86
# 586    67  -3     8   23  178     30    15   86
# 509    77  -4    13   39  217     18     3   85
# 514    84  -6     8   51  218      4     9   84
# 513    70  -6    29   35  206      4     6   84
# 589    81  -4     8   61  229      2     4   84
# 511    76  -6    15   61  209      0     7   84
# 518    78  -5    13   80  209     11     5   83

# %% [markdown]
# Now, the 10 most frequent genres are visualized.

# %% [markdown]
# ## How does the popularity (pop) of songs vary across different genres (top genre)?

# %%
genre_popularity = songs.groupby('top genre')['pop'].mean()

sorted_genre_popularity = genre_popularity.sort_values(ascending=False)

sorted_genre_popularity
# Out:
# top genre
# escape room                  90.000000
# brostep                      86.000000
# alternative r&b              84.000000
# irish singer-songwriter      81.000000
# danish pop                   80.000000
# celtic rock                  80.000000
# electronic trap              79.500000
# edm                          78.200000
# canadian contemporary r&b    77.666667
# electropop                   77.461538
# contemporary country         76.000000
# pop                          74.833333
# electro                      74.500000
# detroit hip hop              73.500000
# canadian hip hop             73.500000
# metropopolis                 73.000000
# chicago rap                  73.000000
# canadian pop                 72.235294
# house                        72.000000
# tropical house               71.666667
# electro house                70.000000
# hip hop                      70.000000
# australian hip hop           70.000000
# boy band                     69.666667
# indie pop                    69.500000
# baroque pop                  67.500000
# complextro                   67.333333
# big room                     65.600000
# barbadian pop                65.400000
# australian pop               65.400000
# dance pop                    64.363914
# art pop                      62.750000
# australian dance             62.333333
# latin                        62.250000
# british soul                 62.181818
# downtempo                    61.500000
# belgian edm                  60.000000
# neo mellow                   60.000000
# permanent wave               58.750000
# candy pop                    58.500000
# acoustic pop                 58.500000
# french indie pop             58.000000
# folk-pop                     56.500000
# colombian pop                56.000000
# hip pop                      55.500000
# moroccan pop                 53.000000
# atl hip hop                  50.000000
# hollywood                    37.000000
# alaska indie                 36.000000
# canadian latin               18.000000
# Name: pop, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sorted_genre_popularity.plot(kind='bar', color='skyblue')
plt.title('Average Popularity by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Popularity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Interestingly, the most common genres are not the most popular.

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.barplot(x='top genre', y='pop', data=songs)
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.title('Popularity of Songs by Genre')
plt.xticks(rotation=90)
plt.show()

# %%
# Get the top 10 genres based on popularity
top10genres = songs['top genre'].value_counts().nlargest(10).index

dftop10genres = songs[songs['top genre'].isin(top10genres)]

plt.figure(figsize=(12, 6))
sns.barplot(x='top genre', y='pop', data=dftop10genres, order=top10genres)
plt.xlabel('Genre')
plt.ylabel('Popularity')
plt.title('Popularity of Songs by Genre (Top 10)')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Which artists are popular over time?

# %%
most_frequent_artists = songs["artist"].value_counts().head(5)
most_frequent_artists
# Out:
# artist
# Katy Perry       17
# Justin Bieber    16
# Rihanna          15
# Maroon 5         15
# Lady Gaga        14
# Name: count, dtype: int64

# %% [markdown]
# Additionally, we want to find out if the most common genre changes from year to year.

# %%
frequentgenres_year = songs.groupby("year")["top genre"].apply(lambda x: x.value_counts().index[0])
frequentgenres_year
# Out:
# year
# 2010    dance pop
# 2011    dance pop
# 2012    dance pop
# 2013    dance pop
# 2014    dance pop
# 2015    dance pop
# 2016    dance pop
# 2017    dance pop
# 2018    dance pop
# 2019          pop
# Name: top genre, dtype: object

# %% [markdown]
# ## What is the average energy and danceability of different genres?

# %%
avg = songs.groupby('top genre')[[ 'nrgy', 'dnce']].mean()
sorted_avg = avg.sort_values(by='nrgy', ascending=False).head(10)

sorted_avg.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Average Value')
plt.title('Average Energy and Danceability of Genres')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# The results above show, that "french indie pop" has the highest mean value for energy, followed by electro house and indie pop.

# %%
french_indiepop = songs[songs['top genre'] == 'french indie pop']
artists = french_indiepop['artist'].value_counts()
top_artists = artists.head(5)
unique_artists = french_indiepop['artist'].unique()

unique_artists
artists
# Out:
# artist
# Lilly Wood and The Prick    1
# Name: count, dtype: int64

# %% [markdown]
# Although the result for "french indie pop" may not be very significant, due to the fact that there is only one song in the dataset associated with this genre.

# %% [markdown]
# ## Does the popularity of a song correlate with its energy level?

# %%
correlation = songs['pop'].corr(songs['nrgy'])
print("Correlation between Popularity and Energy:", correlation)

plt.scatter(songs['nrgy'], songs['pop'])
plt.xlabel('Energy Level')
plt.ylabel('Popularity')
plt.title('Correlation Popularity and Energy')
plt.show()
# Out:
# Correlation between Popularity and Energy: -0.05764503617766647

# %% [markdown]
# The results don´t indicate a strong correlation between popularity and the energy level of a song. If so, there is a very weak negative correlation between popularity and energy.

# %% [markdown]
# ## Is there a relationship between the tempo (bpm) and energy (nrgy) of songs?

# %%
correlation = songs['bpm'].corr(songs['nrgy'])

print("Correlation between bpm and Energy:", correlation)

plt.scatter(songs['bpm'], songs['nrgy'])
plt.xlabel('bpm')
plt.ylabel('Energy')
plt.title('Correlation bpm and Energy')
plt.show()
# Out:
# Correlation between bpm and Energy: 0.12617006494310276

# %% [markdown]
# The results don´t indicate a strong correlation between bpm and the energy level of a song.

# %% [markdown]
# ## Machine Learining

# %% [markdown]
# ### Research Question:
# Can we predict the popularity of a song based on its features?

# %%
songs.dtypes
# Out:
# title        object
# artist       object
# top genre    object
# year          int64
# bpm           int64
# nrgy          int64
# dnce          int64
# dB            int64
# live          int64
# val           int64
# dur           int64
# acous         int64
# spch          int64
# pop           int64
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = songs.select_dtypes(include='number')

songs_corr = numeric_columns.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(songs_corr, annot=True, cmap='coolwarm')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# According to the heatmap, there are no very strong correlations in general. Based on these results, the prediciton of popularity based on the features of a song won´t be very significant.

# %%
#text to binary
songs = pd.get_dummies(songs, columns = ['title','artist', 'top genre'])

# %%
correlation = songs['pop'].corr(songs['dB'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.15689721632507794

# %%
correlation = songs['pop'].corr(songs['dnce'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.1160544446144211

# %%
correlation = songs['pop'].corr(songs['nrgy'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: -0.05764503617766647

# %%
correlation = songs['pop'].corr(songs['val'])
print("Correlation coefficient:", correlation)
# Out:
# Correlation coefficient: 0.0389525866357596

# %% [markdown]
# The results above show that there is no strong correlation between any of the features and the popularity.

# %%
songs.head(5)
# Out:
#    year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  ...
# 0  2010   97    89    67  -4     8   80  217     19     4  ...  \
# 1  2010   87    93    75  -5    52   64  263     24    23  ...
# 2  2010  120    84    76  -3    29   71  200     10    14  ...
# 3  2010  119    92    70  -4     8   71  295      0     4  ...
# 4  2010  109    84    64  -5     9   43  221      2     4  ...
#
#    top genre_house  top genre_indie pop  top genre_irish singer-songwriter
# 0            False                False                              False  \
# 1            False                False                              False
# 2            False                False                              False
# 3            False                False                              False
# 4            False                False                              False
#
#    top genre_latin  top genre_metropopolis  top genre_moroccan pop
# 0            False                   False                   False  \
# 1            False                   False                   False
# 2            False                   False                   False
# 3            False                   False                   False
# 4            False                   False                   False
#
#    top genre_neo mellow  top genre_permanent wave  top genre_pop
# 0                  True                     False          False  \
# 1                 False                     False          False
# 2                 False                     False          False
# 3                 False                     False          False
# 4                 False                     False           True
#
#    top genre_tropical house
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 829 columns]

# %%
new_songs = songs.drop(["year", "live", "acous", 'spch'], axis=1)
#new_songs = pd.get_dummies(new_songs, columns = ['title','artist', 'top genre'])
new_songs
# Out:
#      bpm  nrgy  dnce  dB  val  dur  pop  title_#Beautiful  title_#SELFIE
# 0     97    89    67  -4   80  217   83             False          False  \
# 1     87    93    75  -5   64  263   82             False          False
# 2    120    84    76  -3   71  200   80             False          False
# 3    119    92    70  -4   71  295   79             False          False
# 4    109    84    64  -5   43  221   78             False          False
# ..   ...   ...   ...  ..  ...  ...  ...               ...            ...
# 598  104    66    61  -7   16  176   75             False          False
# 599   95    79    75  -6   61  206   75             False          False
# 600  136    76    53  -5   65  260   70             False          False
# 601  114    79    60  -6   24  217   69             False          False
# 602  150    44    70  -9   23  213   67             False          False
#
#      title_#thatPOWER  ...  top genre_house  top genre_indie pop
# 0               False  ...            False                False  \
# 1               False  ...            False                False
# 2               False  ...            False                False
# 3               False  ...            False                False
# 4               False  ...            False                False
# ..                ...  ...              ...                  ...
# 598             False  ...            False                False
# 599             False  ...            False                False
# 600             False  ...            False                False
# 601             False  ...            False                False
# 602             False  ...            False                False
#
#      top genre_irish singer-songwriter  top genre_latin
# 0                                False            False  \
# 1                                False            False
# 2                                False            False
# 3                                False            False
# 4                                False            False
# ..                                 ...              ...
# 598                              False            False
# 599                              False            False
# 600                              False            False
# 601                              False            False
# 602                              False            False
#
#      top genre_metropopolis  top genre_moroccan pop  top genre_neo mellow
# 0                     False                   False                  True  \
# 1                     False                   False                 False
# 2                     False                   False                 False
# 3                     False                   False                 False
# 4                     False                   False                 False
# ..                      ...                     ...                   ...
# 598                   False                   False                 False
# 599                   False                   False                 False
# 600                   False                   False                 False
# 601                   False                   False                 False
# 602                   False                   False                 False
#
#      top genre_permanent wave  top genre_pop  top genre_tropical house
# 0                       False          False                     False
# 1                       False          False                     False
# 2                       False          False                     False
# 3                       False          False                     False
# 4                       False           True                     False
# ..                        ...            ...                       ...
# 598                     False          False                     False
# 599                     False           True                     False
# 600                     False          False                     False
# 601                     False          False                     False
# 602                     False          False                     False
#
# [603 rows x 825 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

x = new_songs[['dnce', 'nrgy','val', 'dB']]
y = new_songs['pop']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

#mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

#R-squared score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 205.23303849849816
# R-squared: 0.0543375453838596

# %% [markdown]
# The best results are obtained with test_size = 0.4, although the mean squared error and the results for R-squared don´t look like the model is able to make a valid prognosis.

# %%
x = new_songs[['val', 'dnce']]
y = new_songs['pop']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 212.79483751984014
# R-squared: 0.019494668836531726

# %% [markdown]
# I tried varying the independent variables with different combinations, not only the one shown above. It does not improve the results. The results indicate, that there seems to be no real linear-regression relationship between the variables. This machine learning model does not seem to be appropriate in the given context.

# %% [markdown]
# The heatmap indicates, that there is a stronger correlation between valence (the higher the value, the more positive mood for the song) and the "dance", "energy" and "dB" values.

# %%
x = new_songs[['dnce', 'nrgy','dB']]
y = new_songs['val']

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

#mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

#R-squared score
r2 = r2_score(y_test, y_pred)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 375.9485161277807
# R-squared: 0.32862373145608537

# %% [markdown]
# The results obtained here are more significant, although still not very good. In general the use of linear regression does not lead to meaningful results in the context of this dataset.

# %% [markdown]
# ### Literature
# - https://www.kaggle.com/code/aeryan/spotify-music-analysis
# - https://www.kaggle.com/code/arpita28/analysis-of-spotify-trends
# - https://www.kaggle.com/code/pelinsoylu/spotify-popularity-prediction-ml-practice
# - https://www.kaggle.com/code/juanreyes1738/linear-regression-for-top-50-songs
# - https://www.kaggle.com/code/huanntran100/spotify-song-popularity-prediction
